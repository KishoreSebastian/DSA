# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Read the dataset to python environment.
iris_data=pd.read_excel('/content/iris.xls')
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#displaying the columns
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#Import the pandas library
import pandas as pd
# Import the numpy library
import numpy as np

#Mean of each column
iris_data = pd.read_excel('/content/iris.xls')
iris_data.select_dtypes(include=np.number).mean() # Calculate the mean of numerical columns
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
iris_data['SL'].mean()
# Out:
# 5.843333333333334

# %%
iris_data['SW'].mean()
# Out:
# 3.0540000000000003

# %%
iris_data['PL'].mean()

# %%
iris_data['PW'].mean()
# Out:
# 1.1986666666666668

# %%
#Check for the null values present in the dataset.
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris_data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
import seaborn as sns

#Visualizations
#Scatter Plot
#1
sns.scatterplot(data=iris_data)
# Out:
# <Axes: >

# %%
#Boxplot of Sepal width
#2
sns.boxplot(iris_data['SW'])
# Out:
# <Axes: ylabel='SW'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt # Import the matplotlib library

#Bar chart of Classification and Petal length
#3
plt.bar(iris_data['Classification'],iris_data['PL'],color='Green')
plt.title('\nClassification on Petal length',size=15,color='red')
plt.xlabel("  \nClassification",size=12)
plt.ylabel("Petal length",size=12)
# Out:
# Text(0, 0.5, 'Petal length')
